# %%
import pandas as pd


raw_df = pd.read_csv("../data/raw/longa_nao_vacinados.csv")

# %%
raw_df.info()

# %%
raw_df.head()

# %%
raw_df.tail()

# %%
raw_df.isna().sum().sort_values(ascending=False)

# %%
raw_df["Long_COVID"].value_counts()

# %%
raw_df.nunique().sort_values(ascending=False)
